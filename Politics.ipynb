# %%
import pandas as pd
# read data
pol_data = pd.read_csv("politics.csv")
data = pd.read_csv("stage3.csv")
pop_data = pd.read_csv("gun_ownership.csv")

# %%
from bokeh.io import output_notebook, show
from bokeh.plotting import figure

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="09498d44-aa32-4f63-b763-24d017e5556f">Loading BokehJS ...</span>
#     </div>

# %%
#telt alle percentage bij elkaar, maar is onzin want de populatie is niet in elke staat gelijk

counter = 0
for i in range(1, len(pol_data["Democrat"])):    
    counter += pol_data["Democrat"][i]
print(counter, "the percentage of democratic people")

counter = 0
for i in range(1, len(pol_data["Republican"])):
    counter += pol_data["Republican"][i]
print(counter, "the percentage of replublican people")

counter = 0
for i in range(1, len(pol_data["Other"])):
    counter += pol_data["Other"][i]
print(counter, "the percentage of other people")
# Out:
# 2245.05 the percentage of democratic people
# 2404.0499999999997 the percentage of replublican people
# 350.9 the percentage of other people

# %%
# per staat het aantal democraten
P_S = {}

for i in range(len(pop_data["population"])):
    if pop_data["state"][i] not in P_S:
        P_S[pop_data["state"][i]] = pop_data["population"][i]

# percentage voorkeur per staat
D_S = {}

for i in range(len(pol_data["Democrat"])):
    if pol_data["State"][i] not in D_S:
        D_S[pol_data["State"][i]] = pol_data["Democrat"][i]

VForVis = []
USState = []    
    
for state in P_S:
    USState.append(state)
    VForVis.append(int(P_S[state]/100*D_S[state]))

# %%
print(USState, VForVis)
# Out:
# ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'District of Columbia', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming'] [1674963, 270395, 3166442, 1010939, 24405975, 2700405, 1958072, 510693, 627905, 10034740, 4759968, 888214, 471987, 7147369, 2527390, 1313019, 1050180, 1455628, 1801126, 638964, 3651278, 4116577, 4709184, 2589775, 1196922, 2331701, 375551, 647065, 1436660, 630845, 4952203, 1007702, 11713130, 4743237, 205693, 5078490, 1137198, 2074287, 6077507, 576549, 2043410, 276031, 2331789, 12238907, 851763, 353488, 4212140, 3890977, 479931, 2692001, 125305]

# %%
# create a new plot using figure
p = figure(plot_width=400, plot_height=400)

# add a square renderer with a size, color, alpha, and sizes
p.asterisk(USState, VForVis, size=len(USState), color="firebrick", alpha=0.6)

show(p) # show the results
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="2ef2ef98-c7c6-4606-a4cf-e4353e2a3c04"></div>
# </div>
